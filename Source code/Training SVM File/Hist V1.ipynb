# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#!/usr/bin/env python
# coding: utf-8

# In[1]:
from skimage import feature
import numpy as np
import imutils
import cv2
import sys
import math
import glob
import os
import natsort
from pathlib import Path
import shutil
import time
import scipy.io

from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
import pandas as pd
from matplotlib import pyplot as plt
import glob

from numpy import unique
from numpy import hstack
from numpy import vstack
from numpy import where
from matplotlib import pyplot
from sklearn.datasets import make_blobs

import xlwt
from xlwt import Workbook
import openpyxl
# %%
NAMES = ['1_tatta', '2_natta', '4_kuditta_mettu', '5_kuditta_nattal',\
         '6_kuditta_tattal','8_tei_tei_dhatta', \
   '9_katti_kartari','10_utsanga', '11_mandi',\
            '13_tirmana','14_sarika', '15_joining']
#### '6_kuditta_tattal',
# NAMES = ['15_joining', '8_tei_tei_dhatta', \
#    '9_katti_kartari','10_utsanga', '11_mandi',\
#             '13_tirmana','14_sarika', ]

# NAMES = ['6_kuditta_tattal']
ALL_CSVFILE = '/content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/'
i = 1
f = open(os.path.join(ALL_CSVFILE, 'Results.csv'), 'a')
print('nomenclature',
      ',',
      'accuracy_mf_kf',
      ',',
      'accuracy_mf',
      ',',
      'accuracy_kf',
      ',',
      'precision_mf',
      ',',
      'precision_kf',
      ',',
      'recall_mf',
      ',',
      'recall_kf',
      ',',
      'f1_mf',
      ',',
      'f1_kf',
      file=f)
f.close()

for NAME in NAMES:
    NAME_ = NAME + ''
    NAME2 = '_Hist'

    NAME3 = NAME_ + NAME2

    PATH = os.path.join(
        '/content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/',
        NAME3)
    PATH = PATH + '/'
    

    extracted_path = os.path.join(PATH ,  '*.mat')
    print(extracted_path)

    SAVE_FILE = NAME + '.csv'

    nomenclature = NAME

    X_init = np.empty((1, 9))
    Y_init = np.empty((1, 1))

    for filename in glob.glob(extracted_path):
        print(i, '\t', filename)
        head, tail = os.path.split(filename)
        # print(tail)

        mat = scipy.io.loadmat(filename)

        X_data = mat['X_final']
        Y_data = mat['Y_final']

        # print(X_data.shape, Y_data.shape)

        ###     For all train
        X_init = np.vstack((X_init, X_data))
        Y_init = np.vstack((Y_init, Y_data))
#%%
##########delete first row and column
# print(X_init.shape)
# print(Y_init.shape)
    X_init = X_init[1:, :]
    Y_init = Y_init[1:, :]

    X = np.nan_to_num(X_init)
    Y = Y_init.ravel()

    print(X.shape)
    print(Y.shape)

    #### Split dataset into training set and test set
    X_train, X_test, y_train, y_test = train_test_split(
        X, Y, stratify=Y, test_size=0.2,
        random_state=3)  # 70% training and 30% test

    y_train_len = len(y_train)
    n_mf_train = np.count_nonzero(y_train)
    n_kf_train = y_train_len - n_mf_train
    percent_mf_train = 100 * (n_mf_train / y_train_len)
    percent_kf_train = 100 * (n_kf_train / y_train_len)

    print(percent_mf_train, percent_kf_train)
    #########################################################################
    #########################################################################
    #########################################################################
    kernel = 'linear'
    #Create a svm Classifier
    clf = svm.SVC(kernel=kernel,
                  class_weight={
                      1: percent_kf_train / 10,
                      0: percent_mf_train / 10
                  })  # Linear Kernel
    # clf = svm.SVC(kernel=kernel)  # Linear Kernel

    #Train the model using the training sets
    clf.fit(X_train, y_train)

    #Predict the response for test dataset
    y_pred = clf.predict(X_test)
    # Print the confusion matrix

    accuracy = (metrics.accuracy_score(y_test, y_pred)) * 100

    cm = metrics.confusion_matrix(y_test, y_pred)

    TN = cm[0][0]
    FN = cm[1][0]
    TP = cm[1][1]
    FP = cm[0][1]

    accuracy_mf_kf = accuracy
    accuracy_mf = (TP / (TP + FN)) * 100
    accuracy_kf = (TN / (TN + FP)) * 100

    precision_mf = (TP / (TP + FP)) * 100
    precision_kf = (TN / (TN + FN)) * 100

    recall_mf = (TP / (TP + FN)) * 100

    recall_mf = (TP / (TP + FN)) * 100
    recall_kf = (TN / (TN + FP)) * 100

    f1_mf = 2 * precision_mf * recall_mf / (precision_mf + recall_mf)
    f1_kf = 2 * precision_kf * recall_kf / (precision_kf + recall_kf)

    train_accuracy = (clf.score(X_train, y_train)) * 100
    test_accuracy = (clf.score(X_test, y_test)) * 100

    # y_len = len(Y_init)
    # n_mf = np.count_nonzero(Y_init)
    # n_kf = y_len - n_mf
    # percent_mf = 100 * (n_mf / y_len)
    # percent_kf = 100 * (n_kf / y_len)

    f = open(os.path.join(ALL_CSVFILE, 'Results.csv'), 'a')
    print(nomenclature,
          ',',
          "{:.2f}".format(accuracy_mf_kf),
          ',',
          "{:.2f}".format(accuracy_mf),
          ',',
          "{:.2f}".format(accuracy_kf),
          ',',
          "{:.2f}".format(precision_mf),
          ',',
          "{:.2f}".format(precision_kf),
          ',',
          "{:.2f}".format(recall_mf),
          ',',
          "{:.2f}".format(recall_kf),
          ',',
          "{:.2f}".format(f1_mf),
          ',',
          "{:.2f}".format(f1_kf),
          file=f)
    f.close()

    print(
        nomenclature,
        ',',
        "{:.2f}".format(accuracy_mf_kf),
        ',',
        "{:.2f}".format(accuracy_mf),
        ',',
        "{:.2f}".format(accuracy_kf),
        ',',
        "{:.2f}".format(precision_mf),
        ',',
        "{:.2f}".format(precision_kf),
        ',',
        "{:.2f}".format(recall_mf),
        ',',
        "{:.2f}".format(recall_kf),
        ',',
        "{:.2f}".format(f1_mf),
        ',',
        "{:.2f}".format(f1_kf),
    )
# %%
# Out:
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_4_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_5_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_5_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_5_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_6_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_6_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_6_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_7_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_7_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_7_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_8_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_8_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/1_tatta_Hist/1_Tatta_8_Dancer_3.mat
# (11678, 9)
# (11678,)
# 30.539499036608863 69.46050096339114
# 1_tatta , 52.10 , 66.48 , 45.78 , 35.01 , 75.66 , 66.48 , 45.78 , 45.86 , 57.04
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_4_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_5_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_5_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_5_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_6_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_6_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_6_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_7_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_7_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_7_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_8_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_8_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/2_natta_Hist/2_Natta_8_Dancer_3.mat
# (16065, 9)
# (16065,)
# 43.86865857454092 56.13134142545907
# 2_natta , 59.26 , 64.30 , 55.32 , 52.92 , 66.49 , 64.30 , 55.32 , 58.06 , 60.39
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/4_kuditta_mettu_Hist/4_Kuditta_mettu_4_Dancer_3.mat
# (7723, 9)
# (7723,)
# 40.9841372612496 59.0158627387504
# 4_kuditta_mettu , 71.07 , 62.24 , 77.19 , 65.45 , 74.66 , 62.24 , 77.19 , 63.81 , 75.90
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_4_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_5_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_5_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_6_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_6_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/5_kuditta_nattal_Hist/5_Kuditta_nattal_6_Dancer_3.mat
# (13727, 9)
# (13727,)
# 57.043985065112466 42.956014934887534
# 5_kuditta_nattal , 67.73 , 62.67 , 74.47 , 76.54 , 60.01 , 62.67 , 74.47 , 68.91 , 66.46
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_5_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_5_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/6_kuditta_tattal_Hist/6_Kuditta_tattal_5_Dancer_3.mat
# (17920, 9)
# (17920,)
# 59.65401785714286 40.345982142857146
# 6_kuditta_tattal , 54.72 , 44.95 , 69.16 , 68.30 , 45.93 , 44.95 , 69.16 , 54.22 , 55.20
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/8_tei_tei_dhatta_Hist/8_Tei_tei_dhatta_3_Dancer_3.mat
# (4650, 9)
# (4650,)
# 73.06451612903226 26.93548387096774
# 8_tei_tei_dhatta , 54.19 , 45.51 , 77.69 , 84.66 , 34.51 , 45.51 , 77.69 , 59.20 , 47.79
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/9_katti_kartari_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/9_katti_kartari_Hist/9_Katti_kartari_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/9_katti_kartari_Hist/9_Katti_kartari_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/9_katti_kartari_Hist/9_Katti_kartari_1_Dancer_3.mat
# (1959, 9)
# (1959,)
# 65.60306317804722 34.39693682195278
# 9_katti_kartari , 68.88 , 63.04 , 80.00 , 85.71 , 53.20 , 63.04 , 80.00 , 72.65 , 63.91
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/10_utsanga_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/10_utsanga_Hist/10_Utsanga_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/10_utsanga_Hist/10_Utsanga_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/10_utsanga_Hist/10_Utsanga_1_Dancer_3.mat
# (950, 9)
# (950,)
# 71.05263157894737 28.947368421052634
# 10_utsanga , 43.68 , 31.11 , 74.55 , 75.00 , 30.60 , 31.11 , 74.55 , 43.98 , 43.39
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/11_mandi_Hist/11_Mandi_2_Dancer_3.mat
# (9449, 9)
# (9449,)
# 52.162984521762134 47.83701547823786
# 11_mandi , 72.75 , 67.04 , 78.98 , 77.67 , 68.72 , 67.04 , 78.98 , 71.97 , 73.49
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/13_tirmana_Hist/13_Tirmana_3_Dancer_2.mat
# (5708, 9)
# (5708,)
# 61.97985107314936 38.02014892685063
# 13_tirmana , 47.90 , 32.49 , 73.04 , 66.28 , 39.87 , 32.49 , 73.04 , 43.60 , 51.59
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_3_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_4_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_4_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/14_sarika_Hist/14_Sarika_4_Dancer_3.mat
# (7405, 9)
# (7405,)
# 61.951384199864954 38.048615800135046
# 14_sarika , 47.81 , 33.91 , 70.39 , 65.06 , 39.58 , 33.91 , 70.39 , 44.59 , 50.67
# /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/*.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_1_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_1_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_1_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_2_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_2_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_2_Dancer_3.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_3_Dancer_1.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_3_Dancer_2.mat
# 1 	 /content/drive/My Drive/Final Result V1/Final Result V1/Resized_Hist/15_joining_Hist/15_Joining_3_Dancer_3.mat
# (3241, 9)
# (3241,)
# 58.64197530864198 41.358024691358025
# 15_joining , 65.79 , 62.11 , 71.00 , 75.16 , 57.01 , 62.11 , 71.00 , 68.01 , 63.25
